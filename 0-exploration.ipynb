# %%
import numpy as np
import scipy as sp
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
viols = pd.read_csv("./data/viols.csv")
viols.head(n=2)
## We can improve by specifying dtype option for the read_csv to parse. Remember that 
## since read_csv automatically recognizes the dtypes after reading the whole dataset. So if 
## we provide upfront dtypes, it can start reading datasets right away, which saves a lot of 
## time consuming.
# Out:
# C:\Users\Duy-Manh\Anaconda2\lib\site-packages\pandas\io\parsers.py:1164: DtypeWarning: Columns (7,11,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#    Unnamed: 0  TicketID TicketNumber                  AgencyName  \
# 0           1     26288  05000001DAH  Department of Public Works
# 1           2     19800  05000025DAH  Department of Public Works
#
#                     ViolName  ViolationStreetNumber ViolationStreetName  \
# 0  Group, LLC, Grand Holding                   2566    GRAND BLVD
# 1        JACKSON, RAECHELLE                   19014    ASHTON
#
#   MailingStreetNumber   MailingStreetName MailingCity    ...     StateFee  \
# 0                 743  Beaubien, Ste. 201     Detroit    ...       $10.00
# 1               20501              HEYDEN     DETROIT    ...       $10.00
#
#   CleanUpCost JudgmentAmt       PaymentStatus Void ViolationCategory  \
# 0       $0.00    $1680.00        PAID IN FULL    0                 0
# 1       $0.00     $140.00  NO PAYMENT APPLIED    0                 0
#
#                                     ViolationAddress  \
# 0  2566 GRAND BLVD\r\nDetroit, MI\r\n(42.36318237...
# 1  19014 ASHTON\r\nDetroit, MI\r\n(42.42939076200...
#
#                                       MailingAddress        lat        lng
# 0  743 Beaubien\r\nDetroit, MI 48226\r\n(42.33373...  42.363182 -83.091677
# 1  20501 HEYDEN\r\nDETROIT, MI 48219\r\n(42.44217...  42.429391 -83.220394
#
# [2 rows x 34 columns]

# %% [markdown]
# More on the fields and the API of the dataset source:
# https://dev.socrata.com/foundry/data.detroitmi.gov/ujjt-auyi

# %% [markdown]
# We can see that pandas.read_csv() methods work very well. By comparision, we can print the first 5 lines of the file in the following program, which does not work that well since lines are broken by EOL character of "\n", even the character is inside "".

# %% [markdown]
# In order to parse correctly like the pandas.read_csv() method, we can improve the above code as follows

# %%
viols.TicketIssuedDT.head()
# Out:
# 0    01/01/38440 12:00:00 AM
# 1    01/01/38383 12:00:00 AM
# 2    01/01/38383 12:00:00 AM
# 3    01/01/38385 12:00:00 AM
# 4    01/01/38385 12:00:00 AM
# Name: TicketIssuedDT, dtype: object

# %%
## we create a modified next function of the file so that it skips the "\n" character enclosed between " "
def modinext(f): # f as a file
    line = ""
    while True:
        line += next(f)
        if line.count('\"') % 2 == 0:
            return line

# to see the first 5 lines
Nblines = 4
with open("./data/detroit-blight-violations.csv") as f:
    head = [modinext(f) for x in xrange(Nblines)] # use xrange instead of range when we dont use x. Just use for iteration
for i,line in enumerate(head):
    print "Line "+ str(i) + " : "+ line
# Out:
# Line 0 : TicketID,TicketNumber,AgencyName,ViolName,ViolationStreetNumber,ViolationStreetName,MailingStreetNumber,MailingStreetName,MailingCity,MailingState,MailingZipCode,NonUsAddressCode,Country,TicketIssuedDT,TicketIssuedTime,HearingDT,CourtTime,ViolationCode,ViolDescription,Disposition,FineAmt,AdminFee,LateFee,StateFee,CleanUpCost,JudgmentAmt,PaymentStatus,Void,ViolationCategory,ViolationAddress,MailingAddress
#
# Line 1 : 26288,05000001DAH,Department of Public Works,"Group, LLC, Grand Holding",2566,GRAND BLVD      ,743,"Beaubien, Ste. 201",Detroit,MI,48226,N/A,,01/01/38440 12:00:00 AM,12:00:00,01/01/38474 12:00:00 AM, 9:00AM,22-2-20,Burning solid waste  in open fires,Responsible By Determination,$1500.00,$20.00,$150.00,$10.00,$0.00,$1680.00,PAID IN FULL,0,0,"2566 GRAND BLVD
# Detroit, MI
# (42.36318237000006, -83.09167672099994)","743 Beaubien
# Detroit, MI 48226
# (42.33373063000005, -83.04181755199994)"
#
# Line 2 : 19800,05000025DAH,Department of Public Works,"JACKSON, RAECHELLE ",19014,ASHTON          ,20501,HEYDEN,DETROIT,MI,48219,N/A,,01/01/38383 12:00:00 AM,10:15:00,01/01/38425 12:00:00 AM,1:30PM,22-2-22,Bulk solid waste deposited more than 24 hours before designated time,Not responsible By Determination,$100.00,$20.00,$10.00,$10.00,$0.00,$140.00,NO PAYMENT APPLIED,0,0,"19014 ASHTON
# Detroit, MI
# (42.429390762000025, -83.22039357799997)","20501 HEYDEN
# DETROIT, MI 48219
# (42.44217763300003, -83.24182717199994)"
#
# Line 3 : 19804,05000026DAH,Department of Public Works,"TALTON, CAROL ANN",18735,STAHELIN        ,18735,STAHELI N,DETROIT,MI,48219,N/A,,01/01/38383 12:00:00 AM,10:35:00,01/01/38425 12:00:00 AM,1:30PM,22-2-22,Bulk solid waste deposited more than 24 hours before designated time,Responsible By Determination,$100.00,$20.00,$10.00,$10.00,$0.00,$140.00,PAID IN FULL,0,0,"18735 STAHELIN
# Detroit, MI
# (42.428707459000066, -83.22754809599996)","18735 STAHELI N
# DETROIT, MI 48219
# (42.428707459000066, -83.22754809599996)"

# %%
dviolations.describe()
# Out:
#             TicketID  ViolationStreetNumber   Void  ViolationCategory
# count  307804.000000           3.078040e+05  99133      307804.000000
# mean   182967.015269           1.200063e+04      0           0.006553
# std     94107.561832           4.123486e+05      0           0.080684
# min     18645.000000          -1.106400e+04      0           0.000000
# 25%    101805.750000           4.936000e+03      0           0.000000
# 50%    183824.500000           1.062450e+04      0           0.000000
# 75%    265211.250000           1.589500e+04      0           0.000000
# max    339184.000000           2.222222e+08      0           1.000000

# %%
d311 = pd.read_csv("./data/detroit-311.csv")
d311.head(n=3)
# Out:
#    ticket_id             city     issue_type ticket_status  \
# 0    1516722  City of Detroit  Clogged Drain  Acknowledged
# 1    1525361  City of Detroit  Clogged Drain  Acknowledged
# 2    1525218  City of Detroit  Clogged Drain        Closed
#
#                                    issue_description  rating  \
# 0  Two drains one on each side of street, street ...       3
# 1                          standing water on lumplin       2
# 2             CITZEN CALLED TO REPORT CLOGGED DRAINS       2
#
#   ticket_closed_date_time         acknowledged_at ticket_created_date_time  \
# 0                     NaN  03/06/2015 10:03:38 PM   03/06/2015 09:57:52 PM
# 1                     NaN  03/11/2015 04:23:11 PM   03/11/2015 04:14:29 PM
# 2  08/15/2015 12:03:43 AM  03/11/2015 03:39:05 PM   03/11/2015 03:26:20 PM
#
#   ticket_last_updated_date_time  \
# 0        04/12/2015 01:01:10 AM
# 1        04/07/2015 02:04:44 PM
# 2        08/15/2015 12:03:44 AM
#
#                                            address        lat        lng  \
# 0  13120-13130 Ilene Street Detroit, MI 48238, USA  42.383998 -83.161039
# 1            1485 E. Outer Drive Detroit, Michigan  42.440471 -83.080919
# 2                 15460 Eastburn Detroit, Michigan  42.445244 -82.962038
#
#                           location image
# 0  (42.3839977668, -83.1610385642)   NaN
# 1         (42.4404708, -83.080919)   NaN
# 2          (42.445244, -82.962038)   NaN

# %%
d311.dtypes
# Out:
# ticket_id                          int64
# city                              object
# issue_type                        object
# ticket_status                     object
# issue_description                 object
# rating                             int64
# ticket_closed_date_time           object
# acknowledged_at                   object
# ticket_created_date_time          object
# ticket_last_updated_date_time     object
# address                           object
# lat                              float64
# lng                              float64
# location                          object
# image                             object
# dtype: object

# %%
d311.describe()
# Out:
#             ticket_id        rating           lat           lng
# count    19680.000000  19680.000000  19680.000000  19680.000000
# mean   1699224.357571      2.692530     42.386310    -83.109313
# std     172179.801056      0.801268      0.038308      0.100192
# min    1184398.000000      1.000000     41.879952    -86.550059
# 25%    1591936.500000      2.000000     42.355576    -83.191768
# 50%    1705228.500000      3.000000     42.387895    -83.112410
# 75%    1838304.750000      3.000000     42.419723    -83.037698
# max    1975499.000000     19.000000     42.449849    -82.911434

# %%
dcrime = pd.read_csv("./data/detroit-crime.csv")
dcrime.head(n=3)
# Out:
# C:\Users\Duy-Manh\Anaconda2\lib\site-packages\pandas\io\parsers.py:1164: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#    ROWNUM   CASEID        INCINO        CATEGORY  \
# 0   53256  1953933  1506030028.1         ASSAULT
# 1   17631  1917717  1503010158.1         LARCENY
# 2   11207  1910955  1502080223.1  STOLEN VEHICLE
#
#                              OFFENSEDESCRIPTION  STATEOFFENSEFILECLASS  \
# 0            ASSAULT AND BATTERY/SIMPLE ASSAULT                  13001
# 1  LARCENY - PARTS AND ACCESSORIES FROM VEHICLE                  23006
# 2                                 VEHICLE THEFT                  24001
#
#              INCIDENTDATE  HOUR   SCA  PRECINCT                  COUNCIL  \
# 0  06/03/2015 12:00:00 AM     2  1007        10  City Council District 5
# 1  03/01/2015 12:00:00 AM     9   608         6  City Council District 7
# 2  02/08/2015 12:00:00 AM    18  1105        11  City Council District 3
#
#            NEIGHBORHOOD  CENSUSTRACT                    ADDRESS      LON  \
# 0       PETOSKEY-OTSEGO         5334             09100 PETOSKEY -83.1221
# 1              GRANDALE         5452  00 PLYMOUTH AND MANSFIELD -83.2035
# 2  OUTER DRIVE VAN DYKE         5051      00 E 7 MILE  VAN DYKE -83.0241
#
#        LAT                                        LOCATION
# 0  42.3678            PETOSKEY\n09100\n(42.3676, -83.1219)
# 1  42.3724  00 PLYMOUTH AND MANSFIELD\n(42.3725, -83.2033)
# 2  42.4338       00 E 7 MILE VAN DYKE\n(42.4339, -83.0241)

# %%
ddpermits = pd.read_csv("./data/detroit-demolition-permits.tsv", sep = "\t")
ddpermits.head(n=3)
# Out:
#        PERMIT_NO PERMIT_APPLIED PERMIT_ISSUED PERMIT_EXPIRES     SITE_ADDRESS  \
# 0  BLD2015-03955        8/28/15       8/28/15            NaN     4331  BARHAM
# 1  BLD2015-04083        8/28/15       8/28/15            NaN  9707  BESSEMORE
# 2  BLD2015-03976        8/28/15       8/28/15            NaN  5315  BERKSHIRE
#
#                             BETWEEN1   PARCEL_NO LOT_NUMBER SUBDIVISION  \
# 0         BETWEEN VOIGHT AND WAVENEY  21 65525-6        S15         NaN
# 1         BETWEEN VINTON AND GRATIOT    19 2312.         40         NaN
# 2  BETWEEN SOUTHAMPTON AND FRANKFORT   21 69321.        445         NaN
#
#   CASE_TYPE ...  CONTRACTOR_ADDRESS1 CONTRACTOR_ADDRESS2 CONTRACTOR_CITY  \
# 0       BLD ...          13500 FOLEY                 NaN         DETROIT
# 1       BLD ...          13500 FOLEY                 NaN         DETROIT
# 2       BLD ...          13500 FOLEY                 NaN         DETROIT
#
#    CONTRACTOR_STATE  CONTRACTOR_ZIP  CONDITION_FOR_APPROVAL  \
# 0               NaN           48227                     NaN
# 1               NaN           48227                     NaN
# 2               NaN           48227                     NaN
#
#                                        site_location  \
# 0    4331 BARHAM\nDetroit, MI\n(42.394106, -82.9474)
# 1  9707 BESSEMORE\nDetroit, MI\n(42.395122, -83.0...
# 2  5315 BERKSHIRE\nDetroit, MI\n(42.40322, -82.94...
#
#                                       owner_location  \
# 0  65 CADILLAC\nDETROIT, MI\n(42.331741326000042,...
# 1  65 CADILLAC\nDETROIT, MI\n(42.331741326000042,...
# 2  65 CADILLAC\nDETROIT, MI\n(42.331741326000042,...
#
#                                  contractor_location geom
# 0  13500 FOLEY\nDETROIT, MI\n(42.379332, -83.177501)  NaN
# 1  13500 FOLEY\nDETROIT, MI\n(42.379332, -83.177501)  NaN
# 2  13500 FOLEY\nDETROIT, MI\n(42.379332, -83.177501)  NaN
#
# [3 rows x 55 columns]
